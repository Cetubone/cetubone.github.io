# %% [markdown]
# ---
# title: "从Vina对接到分子动力学模拟计算结合自由能"
# date: 2026-01-29
# description: "Conda介绍及使用方法。"
# categories: [Vina, Gromacs, CHARMM-GUI, dock, md]
# author:
#   - name: CetuBone
#     url: bioziangz@outlook.com
# license: CC BY-NC-SA 4.0
# draft: true
# ---
